# %%
import pandas as pd
import json
import requests

# %%
endpoint = 'http://site.api.espn.com/apis/site/v2/sports/football/college-football/scoreboard'

# %%
from pprint import pprint
response = requests.get(endpoint)
print(response.status_code)
data = response.json()
pprint(json.dumps(data, indent=2))
# Out:
# 200
# ('{\n'
#  '  "leagues": [\n'
#  '    {\n'
#  '      "id": "23",\n'
#  '      "uid": "s:20~l:23",\n'
#  '      "name": "NCAA - Football",\n'
#  '      "abbreviation": "NCAAF",\n'
#  '      "midsizeName": "NCAA Football",\n'
#  '      "slug": "college-football",\n'
#  '      "season": {\n'
#  '        "year": 2025,\n'
#  '        "startDate": "2025-02-01T08:00Z",\n'
#  '        "endDate": "2026-01-21T07:59Z",\n'
#  '        "displayName": "2025",\n'
#  '        "type": {\n'
#  '          "id": "2",\n'
#  '          "type": 2,\n'
#  '          "name": "Regular Season",\n'
#  '          "abbreviation": "reg"\n'
#  '        }\n'
#  '      },\n'
#  '      "logos": [\n'
#  '        {\n'
#  '          "href": '
#  '"https://a.espncdn.com/redesign/assets/img/icons/ESPN-icon-football-college.png",\n'
#  '          "width": 500,\n'
#  '          "height": 500,\n'
#  '          "alt": "",\n'
#  '          "rel": [\n'
#  '            "full",\n'
#  '            "default"\n'
#  '          ],\n'
#  '          "lastUpdated": "2021-08-03T15:56Z"\n'
#  '        },\n'
#  '        {\n'
#  '          "href": '
#  '"https://a.espncdn.com/redesign/assets/img/icons/ESPN-icon-football-college.png",\n'
#  '          "width": 500,\n'
#  '          "height": 500,\n'
#  '          "alt": "",\n'
#  '          "rel": [\n'
#  '            "full",\n'
#  '            "dark"\n'
#  '          ],\n'
#  '          "lastUpdated": "2021-08-03T15:56Z"\n'
#  '        }\n'
#  '      ],\n'
#  '      "calendarType": "list",\n'
#  '      "calendarIsWhitelist": true,\n'
#  '      "calendarStartDate": "2025-02-01T08:00Z",\n'
#  '      "calendarEndDate": "2026-01-21T07:59Z",\n'
#  '      "calendar": [\n'
#  '        {\n'
#  '          "label": "Regular Season",\n'
#  '          "value": "2",\n'
#  '          "startDate": "2025-08-23T07:00Z",\n'
#  '          "endDate": "2025-12-14T07:59Z",\n'
#  '          "entries": [\n'
#  '            {\n'
#  '              "label": "Week 1",\n'
#  '              "alternateLabel": "Week 1",\n'
#  '              "detail": "Aug 23-Sep 1",\n'
#  '              "value": "1",\n'
#  '              "startDate": "2025-08-23T07:00Z",\n'
#  '              "endDate": "2025-09-02T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 2",\n'
#  '              "alternateLabel": "Week 2",\n'
#  '              "detail": "Sep 2-7",\n'
#  '              "value": "2",\n'
#  '              "startDate": "2025-09-02T07:00Z",\n'
#  '              "endDate": "2025-09-08T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 3",\n'
#  '              "alternateLabel": "Week 3",\n'
#  '              "detail": "Sep 8-14",\n'
#  '              "value": "3",\n'
#  '              "startDate": "2025-09-08T07:00Z",\n'
#  '              "endDate": "2025-09-15T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 4",\n'
#  '              "alternateLabel": "Week 4",\n'
#  '              "detail": "Sep 15-21",\n'
#  '              "value": "4",\n'
#  '              "startDate": "2025-09-15T07:00Z",\n'
#  '              "endDate": "2025-09-22T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 5",\n'
#  '              "alternateLabel": "Week 5",\n'
#  '              "detail": "Sep 22-28",\n'
#  '              "value": "5",\n'
#  '              "startDate": "2025-09-22T07:00Z",\n'
#  '              "endDate": "2025-09-29T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 6",\n'
#  '              "alternateLabel": "Week 6",\n'
#  '              "detail": "Sep 29-Oct 5",\n'
#  '              "value": "6",\n'
#  '              "startDate": "2025-09-29T07:00Z",\n'
#  '              "endDate": "2025-10-06T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 7",\n'
#  '              "alternateLabel": "Week 7",\n'
#  '              "detail": "Oct 6-12",\n'
#  '              "value": "7",\n'
#  '              "startDate": "2025-10-06T07:00Z",\n'
#  '              "endDate": "2025-10-13T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 8",\n'
#  '              "alternateLabel": "Week 8",\n'
#  '              "detail": "Oct 13-19",\n'
#  '              "value": "8",\n'
#  '              "startDate": "2025-10-13T07:00Z",\n'
#  '              "endDate": "2025-10-20T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 9",\n'
#  '              "alternateLabel": "Week 9",\n'
#  '              "detail": "Oct 20-26",\n'
#  '              "value": "9",\n'
#  '              "startDate": "2025-10-20T07:00Z",\n'
#  '              "endDate": "2025-10-27T06:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 10",\n'
#  '              "alternateLabel": "Week 10",\n'
#  '              "detail": "Oct 27-Nov 2",\n'
#  '              "value": "10",\n'
#  '              "startDate": "2025-10-27T07:00Z",\n'
#  '              "endDate": "2025-11-03T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 11",\n'
#  '              "alternateLabel": "Week 11",\n'
#  '              "detail": "Nov 3-9",\n'
#  '              "value": "11",\n'
#  '              "startDate": "2025-11-03T08:00Z",\n'
#  '              "endDate": "2025-11-10T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 12",\n'
#  '              "alternateLabel": "Week 12",\n'
#  '              "detail": "Nov 10-16",\n'
#  '              "value": "12",\n'
#  '              "startDate": "2025-11-10T08:00Z",\n'
#  '              "endDate": "2025-11-17T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 13",\n'
#  '              "alternateLabel": "Week 13",\n'
#  '              "detail": "Nov 17-23",\n'
#  '              "value": "13",\n'
#  '              "startDate": "2025-11-17T08:00Z",\n'
#  '              "endDate": "2025-11-24T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 14",\n'
#  '              "alternateLabel": "Week 14",\n'
#  '              "detail": "Nov 24-30",\n'
#  '              "value": "14",\n'
#  '              "startDate": "2025-11-24T08:00Z",\n'
#  '              "endDate": "2025-12-01T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 15",\n'
#  '              "alternateLabel": "Week 15",\n'
#  '              "detail": "Dec 1-7",\n'
#  '              "value": "15",\n'
#  '              "startDate": "2025-12-01T08:00Z",\n'
#  '              "endDate": "2025-12-08T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "Week 16",\n'
#  '              "alternateLabel": "Week 16",\n'
#  '              "detail": "Dec 8-13",\n'
#  '              "value": "16",\n'
#  '              "startDate": "2025-12-08T08:00Z",\n'
#  '              "endDate": "2026-12-14T07:59Z"\n'
#  '            }\n'
#  '          ]\n'
#  '        },\n'
#  '        {\n'
#  '          "label": "Postseason",\n'
#  '          "value": "3",\n'
#  '          "startDate": "2025-12-13T08:00Z",\n'
#  '          "endDate": "2026-01-21T07:59Z",\n'
#  '          "entries": [\n'
#  '            {\n'
#  '              "label": "Bowls",\n'
#  '              "alternateLabel": "Bowls",\n'
#  '              "detail": "Dec 13-Jan 20",\n'
#  '              "value": "1",\n'
#  '              "startDate": "2025-12-13T08:00Z",\n'
#  '              "endDate": "2026-01-21T07:59Z"\n'
#  '            },\n'
#  '            {\n'
#  '              "label": "CFP",\n'
#  '              "alternateLabel": "CFP",\n'
#  '              "detail": "Dec 19-Jan 20",\n'
#  '              "value": "999",\n'
#  '              "startDate": "2025-12-19T08:00Z",\n'
#  '              "endDate": "2026-01-20T07:59Z"\n'
#  '            }\n'
#  '          ]\n'
#  '        },\n'
#  '        {\n'
#  '          "label": "Off Season",\n'
#  '          "value": "4",\n'
#  '          "startDate": "2026-01-21T08:00Z",\n'
#  '          "endDate": "2026-02-01T07:59Z",\n'
#  '          "entries": [\n'
#  '            {\n'
#  '              "label": "All-Star",\n'
#  '              "alternateLabel": "All-Star",\n'
#  '              "detail": "Jan 21-31",\n'
#  '              "value": "1",\n'
#  '              "startDate": "2026-01-21T08:00Z",\n'
#  '              "endDate": "2026-02-01T07:59Z"\n'
#  '            }\n'
#  '          ]\n'
#  '        }\n'
#  '      ]\n'
#  '    }\n'
#  '  ],\n'
#  '  "season": {\n'
#  '    "type": 2,\n'
#  '    "year": 2025\n'
#  '  },\n'
#  '  "week": {\n'
#  '    "number": 8\n'
#  '  },\n'
#  '  "events": [\n'
#  '    {\n'
#  '      "id": "401754564",\n'
#  '      "uid": "s:20~l:23~e:401754564",\n'
#  '      "date": "2025-10-17T23:00Z",\n'
#  '      "name": "Louisville Cardinals at Miami Hurricanes",\n'
#  '      "shortName": "LOU @ MIA",\n'
#  '      "season": {\n'
#  '        "year": 2025,\n'
#  '        "type": 2,\n'
#  '        "slug": "regular-season"\n'
#  '      },\n'
#  '      "week": {\n'
#  '        "number": 8\n'
#  '      },\n'
#  '      "competitions": [\n'
#  '        {\n'
#  '          "id": "401754564",\n'
#  '          "uid": "s:20~l:23~e:401754564~c:401754564",\n'
#  '          "date": "2025-10-17T23:00Z",\n'
#  '          "attendance": 66573,\n'
#  '          "type": {\n'
#  '            "id": "1",\n'
#  '            "abbreviation": "STD"\n'
#  '          },\n'
#  '          "timeValid": true,\n'
#  '          "dateValid": false,\n'
#  '          "neutralSite": false,\n'
#  '          "conferenceCompetition": true,\n'
#  '          "playByPlayAvailable": true,\n'
#  '          "recent": false,\n'
#  '          "venue": {\n'
#  '            "id": "3948",\n'
#  '            "fullName": "Hard Rock Stadium",\n'
#  '            "address": {\n'
#  '              "city": "Miami Gardens",\n'
#  '              "state": "FL",\n'
#  '              "country": "USA"\n'
#  '            },\n'
#  '            "indoor": false\n'
#  '          },\n'
#  '          "competitors": [\n'
#  '            {\n'
#  '              "id": "2390",\n'
#  '              "uid": "s:20~l:23~t:2390",\n'
#  '              "type": "team",\n'
#  '              "order": 0,\n'
#  '              "homeAway": "home",\n'
#  '              "winner": false,\n'
#  '              "team": {\n'
#  '                "id": "2390",\n'
#  '                "uid": "s:20~l:23~t:2390",\n'
#  '                "location": "Miami",\n'
#  '                "name": "Hurricanes",\n'
#  '                "abbreviation": "MIA",\n'
#  '                "displayName": "Miami Hurricanes",\n'
#  '                "shortDisplayName": "Miami",\n'
#  '                "color": "005030",\n'
#  '                "alternateColor": "f47321",\n'
#  '                "isActive": true,\n'
#  '                "venue": {\n'
#  '                  "id": "3948"\n'
#  '                },\n'
#  '                "links": [\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/2390/miami-hurricanes",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "mobile",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/2390/miami-hurricanes",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "roster",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/roster/_/id/2390",\n'
#  '                    "text": "Roster",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "stats",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/stats/_/id/2390",\n'
#  '                    "text": "Statistics",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "schedule",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/schedule/_/id/2390",\n'
#  '                    "text": "Schedule",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  }\n'
#  '                ],\n'
#  '                "logo": '
#  '"https://a.espncdn.com/i/teamlogos/ncaa/500/2390.png",\n'
#  '                "conferenceId": "1"\n'
#  '              },\n'
#  '              "score": "21",\n'
#  '              "linescores": [\n'
#  '                {\n'
#  '                  "value": 7.0,\n'
#  '                  "displayValue": "7",\n'
#  '                  "period": 1\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 3.0,\n'
#  '                  "displayValue": "3",\n'
#  '                  "period": 2\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 3.0,\n'
#  '                  "displayValue": "3",\n'
#  '                  "period": 3\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 8.0,\n'
#  '                  "displayValue": "8",\n'
#  '                  "period": 4\n'
#  '                }\n'
#  '              ],\n'
#  '              "statistics": [],\n'
#  '              "curatedRank": {\n'
#  '                "current": 2\n'
#  '              },\n'
#  '              "records": [\n'
#  '                {\n'
#  '                  "name": "overall",\n'
#  '                  "abbreviation": "Game",\n'
#  '                  "type": "total",\n'
#  '                  "summary": "5-1"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "Home",\n'
#  '                  "type": "home",\n'
#  '                  "summary": "4-1"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "Road",\n'
#  '                  "type": "road",\n'
#  '                  "summary": "1-0"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "vs. Conf.",\n'
#  '                  "type": "vsconf",\n'
#  '                  "summary": "1-1"\n'
#  '                }\n'
#  '              ]\n'
#  '            },\n'
#  '            {\n'
#  '              "id": "97",\n'
#  '              "uid": "s:20~l:23~t:97",\n'
#  '              "type": "team",\n'
#  '              "order": 1,\n'
#  '              "homeAway": "away",\n'
#  '              "winner": true,\n'
#  '              "team": {\n'
#  '                "id": "97",\n'
#  '                "uid": "s:20~l:23~t:97",\n'
#  '                "location": "Louisville",\n'
#  '                "name": "Cardinals",\n'
#  '                "abbreviation": "LOU",\n'
#  '                "displayName": "Louisville Cardinals",\n'
#  '                "shortDisplayName": "Louisville",\n'
#  '                "color": "c9001f",\n'
#  '                "alternateColor": "000000",\n'
#  '                "isActive": true,\n'
#  '                "venue": {\n'
#  '                  "id": "3873"\n'
#  '                },\n'
#  '                "links": [\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/97/louisville-cardinals",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "mobile",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/97/louisville-cardinals",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "roster",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/roster/_/id/97",\n'
#  '                    "text": "Roster",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "stats",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/stats/_/id/97",\n'
#  '                    "text": "Statistics",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "schedule",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/schedule/_/id/97",\n'
#  '                    "text": "Schedule",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  }\n'
#  '                ],\n'
#  '                "logo": '
#  '"https://a.espncdn.com/i/teamlogos/ncaa/500/97.png",\n'
#  '                "conferenceId": "1"\n'
#  '              },\n'
#  '              "score": "24",\n'
#  '              "linescores": [\n'
#  '                {\n'
#  '                  "value": 14.0,\n'
#  '                  "displayValue": "14",\n'
#  '                  "period": 1\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 0.0,\n'
#  '                  "displayValue": "0",\n'
#  '                  "period": 2\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 3.0,\n'
#  '                  "displayValue": "3",\n'
#  '                  "period": 3\n'
#  '                },\n'
#  '                {\n'
#  '                  "value": 7.0,\n'
#  '                  "displayValue": "7",\n'
#  '                  "period": 4\n'
#  '                }\n'
#  '              ],\n'
#  '              "statistics": [],\n'
#  '              "curatedRank": {\n'
#  '                "current": 99\n'
#  '              },\n'
#  '              "records": [\n'
#  '                {\n'
#  '                  "name": "overall",\n'
#  '                  "abbreviation": "Game",\n'
#  '                  "type": "total",\n'
#  '                  "summary": "5-1"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "Home",\n'
#  '                  "type": "home",\n'
#  '                  "summary": "3-1"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "Road",\n'
#  '                  "type": "road",\n'
#  '                  "summary": "2-0"\n'
#  '                },\n'
#  '                {\n'
#  '                  "name": "vs. Conf.",\n'
#  '                  "type": "vsconf",\n'
#  '                  "summary": "2-1"\n'
#  '                }\n'
#  '              ]\n'
#  '            }\n'
#  '          ],\n'
#  '          "notes": [],\n'
#  '          "status": {\n'
#  '            "clock": 0.0,\n'
#  '            "displayClock": "0:00",\n'
#  '            "period": 4,\n'
#  '            "type": {\n'
#  '              "id": "3",\n'
#  '              "name": "STATUS_FINAL",\n'
#  '              "state": "post",\n'
#  '              "completed": true,\n'
#  '              "description": "Final",\n'
#  '              "detail": "Final",\n'
#  '              "shortDetail": "Final"\n'
#  '            }\n'
#  '          },\n'
#  '          "broadcasts": [\n'
#  '            {\n'
#  '              "market": "national",\n'
#  '              "names": [\n'
#  '                "ESPN"\n'
#  '              ]\n'
#  '            }\n'
#  '          ],\n'
#  '          "leaders": [\n'
#  '            {\n'
#  '              "name": "passingYards",\n'
#  '              "displayName": "Passing Leader",\n'
#  '              "shortDisplayName": "PASS",\n'
#  '              "abbreviation": "PYDS",\n'
#  '              "leaders": [\n'
#  '                {\n'
#  '                  "displayValue": "25/35, 271 YDS, 4 INT",\n'
#  '                  "value": 271.0,\n'
#  '                  "athlete": {\n'
#  '                    "id": "4430841",\n'
#  '                    "fullName": "Carson Beck",\n'
#  '                    "displayName": "Carson Beck",\n'
#  '                    "shortName": "C. Beck",\n'
#  '                    "links": [\n'
#  '                      {\n'
#  '                        "rel": [\n'
#  '                          "playercard",\n'
#  '                          "desktop",\n'
#  '                          "athlete"\n'
#  '                        ],\n'
#  '                        "href": '
#  '"https://www.espn.com/college-football/player/_/id/4430841/carson-beck"\n'
#  '                      }\n'
#  '                    ],\n'
#  '                    "headshot": '
#  '"https://a.espncdn.com/i/headshots/college-football/players/full/4430841.png",\n'
#  '                    "jersey": "11",\n'
#  '                    "position": {\n'
#  '                      "abbreviation": "QB"\n'
#  '                    },\n'
#  '                    "team": {\n'
#  '                      "id": "2390"\n'
#  '                    },\n'
#  '                    "active": true\n'
#  '                  },\n'
#  '                  "team": {\n'
#  '                    "id": "2390"\n'
#  '                  }\n'
#  '                }\n'
#  '              ]\n'
#  '            },\n'
#  '            {\n'
#  '              "name": "rushingYards",\n'
#  '              "displayName": "Rushing Leader",\n'
#  '              "shortDisplayName": "RUSH",\n'
#  '              "abbreviation": "RYDS",\n'
#  '              "leaders": [\n'
#  '                {\n'
#  '                  "displayValue": "15 CAR, 113 YDS",\n'
#  '                  "value": 113.0,\n'
#  '                  "athlete": {\n'
#  '                    "id": "5079349",\n'
#  '                    "fullName": "Isaac Brown",\n'
#  '                    "displayName": "Isaac Brown",\n'
#  '                    "shortName": "I. Brown",\n'
#  '                    "links": [\n'
#  '                      {\n'
#  '                        "rel": [\n'
#  '                          "playercard",\n'
#  '                          "desktop",\n'
#  '                          "athlete"\n'
#  '                        ],\n'
#  '                        "href": '
#  '"https://www.espn.com/college-football/player/_/id/5079349/isaac-brown"\n'
#  '                      }\n'
#  '                    ],\n'
#  '                    "headshot": '
#  '"https://a.espncdn.com/i/headshots/college-football/players/full/5079349.png",\n'
#  '                    "jersey": "1",\n'
#  '                    "position": {\n'
#  '                      "abbreviation": "RB"\n'
#  '                    },\n'
#  '                    "team": {\n'
#  '                      "id": "97"\n'
#  '                    },\n'
#  '                    "active": true\n'
#  '                  },\n'
#  '                  "team": {\n'
#  '                    "id": "97"\n'
#  '                  }\n'
#  '                }\n'
#  '              ]\n'
#  '            },\n'
#  '            {\n'
#  '              "name": "receivingYards",\n'
#  '              "displayName": "Receiving Leader",\n'
#  '              "shortDisplayName": "REC",\n'
#  '              "abbreviation": "RECYDS",\n'
#  '              "leaders": [\n'
#  '                {\n'
#  '                  "displayValue": "9 REC, 136 YDS, 2 TD",\n'
#  '                  "value": 136.0,\n'
#  '                  "athlete": {\n'
#  '                    "id": "4869961",\n'
#  '                    "fullName": "Chris Bell",\n'
#  '                    "displayName": "Chris Bell",\n'
#  '                    "shortName": "C. Bell",\n'
#  '                    "links": [\n'
#  '                      {\n'
#  '                        "rel": [\n'
#  '                          "playercard",\n'
#  '                          "desktop",\n'
#  '                          "athlete"\n'
#  '                        ],\n'
#  '                        "href": '
#  '"https://www.espn.com/college-football/player/_/id/4869961/chris-bell"\n'
#  '                      }\n'
#  '                    ],\n'
#  '                    "headshot": '
#  '"https://a.espncdn.com/i/headshots/college-football/players/full/4869961.png",\n'
#  '                    "jersey": "0",\n'
#  '                    "position": {\n'
#  '                      "abbreviation": "WR"\n'
#  '                    },\n'
#  '                    "team": {\n'
#  '                      "id": "97"\n'
#  '                    },\n'
#  '                    "active": true\n'
#  '                  },\n'
#  '                  "team": {\n'
#  '                    "id": "97"\n'
#  '                  }\n'
#  '                }\n'
#  '              ]\n'
#  '            }\n'
#  '          ],\n'
#  '          "groups": {\n'
#  '            "id": "1",\n'
#  '            "name": "Atlantic Coast Conference",\n'
#  '            "shortName": "ACC",\n'
#  '            "isConference": true\n'
#  '          },\n'
#  '          "format": {\n'
#  '            "regulation": {\n'
#  '              "periods": 4\n'
#  '            }\n'
#  '          },\n'
#  '          "startDate": "2025-10-17T23:00Z",\n'
#  '          "broadcast": "ESPN",\n'
#  '          "geoBroadcasts": [\n'
#  '            {\n'
#  '              "type": {\n'
#  '                "id": "1",\n'
#  '                "shortName": "TV"\n'
#  '              },\n'
#  '              "market": {\n'
#  '                "id": "1",\n'
#  '                "type": "National"\n'
#  '              },\n'
#  '              "media": {\n'
#  '                "shortName": "ESPN",\n'
#  '                "logo": '
#  '"https://a.espncdn.com/guid/335fd2d2-97b9-336b-81ee-573eb6bdcffc/logos/default.png",\n'
#  '                "darkLogo": ""\n'
#  '              },\n'
#  '              "lang": "en",\n'
#  '              "region": "us"\n'
#  '            }\n'
#  '          ],\n'
#  '          "highlights": [\n'
#  '            {\n'
#  '              "id": 46632233,\n'
#  '              "cerebroId": "68f304bfc9546c6cde34a313",\n'
#  '              "source": "espn",\n'
#  '              "headline": "Louisville Cardinals vs. Miami Hurricanes: Full '
#  'Highlights",\n'
#  '              "description": "Louisville Cardinals vs. Miami Hurricanes: '
#  'Full Highlights",\n'
#  '              "lastModified": "2025-10-18T03:19:38Z",\n'
#  '              "originalPublishDate": "2025-10-18T03:08:42Z",\n'
#  '              "duration": 94,\n'
#  '              "timeRestrictions": {\n'
#  '                "embargoDate": "2025-10-18T03:08:42Z",\n'
#  '                "expirationDate": "2038-01-01T04:59:59Z"\n'
#  '              },\n'
#  '              "deviceRestrictions": {\n'
#  '                "type": "whitelist",\n'
#  '                "devices": [\n'
#  '                  "desktop",\n'
#  '                  "ipad",\n'
#  '                  "settop",\n'
#  '                  "handset",\n'
#  '                  "tablet"\n'
#  '                ]\n'
#  '              },\n'
#  '              "thumbnail": '
#  '"https://a.espncdn.com/media/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.jpg",\n'
#  '              "links": {\n'
#  '                "web": {\n'
#  '                  "href": "https://www.espn.com/video/clip?id=46632233",\n'
#  '                  "self": {\n'
#  '                    "href": "https://www.espn.com/video/clip?id=46632233",\n'
#  '                    "dsi": {\n'
#  '                      "href": '
#  '"https://www.espn.com/video/clip?id=1b08359549a0a"\n'
#  '                    }\n'
#  '                  },\n'
#  '                  "seo": {\n'
#  '                    "href": "https://www.espn.com/video/clip/_/id/46632233"\n'
#  '                  }\n'
#  '                },\n'
#  '                "mobile": {\n'
#  '                  "source": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.mp4"\n'
#  '                  },\n'
#  '                  "alert": {\n'
#  '                    "href": '
#  '"https://m.espn.com/general/video/videoAlert?vid=46632233"\n'
#  '                  },\n'
#  '                  "streaming": {\n'
#  '                    "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46632233"\n'
#  '                  },\n'
#  '                  "progressiveDownload": {\n'
#  '                    "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46632233"\n'
#  '                  }\n'
#  '                },\n'
#  '                "api": {\n'
#  '                  "self": {\n'
#  '                    "href": '
#  '"https://content.core.api.espn.com/v1/video/clips/46632233"\n'
#  '                  },\n'
#  '                  "artwork": {\n'
#  '                    "href": '
#  '"https://artwork.api.espn.com/artwork/collections/media/f9a3cca2-afc0-4685-ad11-f807c1233f39"\n'
#  '                  }\n'
#  '                },\n'
#  '                "source": {\n'
#  '                  "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_360p30_1464k.mp4",\n'
#  '                  "mezzanine": {\n'
#  '                    "href": '
#  '"https://media.video-origin.espn.com/espnvideo/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.mp4"\n'
#  '                  },\n'
#  '                  "flash": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.smil"\n'
#  '                  },\n'
#  '                  "hds": {\n'
#  '                    "href": '
#  '"https://hds.video-cdn.espn.com/z/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_rel.smil/manifest.f4m"\n'
#  '                  },\n'
#  '                  "HLS": {\n'
#  '                    "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8",\n'
#  '                    "HD": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                    },\n'
#  '                    "cmaf": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8",\n'
#  '                      "9x16": {\n'
#  '                        "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "9x16": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                    },\n'
#  '                    "shield": {\n'
#  '                      "href": '
#  '"https://watch.auth.api.espn.com/video/auth/media/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset"\n'
#  '                    }\n'
#  '                  },\n'
#  '                  "HD": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_720p30_2896k.mp4"\n'
#  '                  },\n'
#  '                  "full": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_360p30_1464k.mp4"\n'
#  '                  }\n'
#  '                },\n'
#  '                "sportscenter": {\n'
#  '                  "href": '
#  '"sportscenter://x-callback-url/showVideo?videoID=46632233&videoDSI=1b08359549a0a"\n'
#  '                }\n'
#  '              },\n'
#  '              "ad": {\n'
#  '                "sport": "ncf",\n'
#  '                "bundle": "ncf_top_plays"\n'
#  '              },\n'
#  '              "tracking": {\n'
#  '                "sportName": "football",\n'
#  '                "leagueName": "NCAA Football",\n'
#  '                "coverageType": "Final Game Highlight",\n'
#  '                "trackingName": "NCF_One-Play (Louisville Cardinals vs. '
#  'Miami Hurricanes: Full Highlights) 2025/10/17 ESHEET",\n'
#  '                "trackingId": '
#  '"dm_20251017_NCF_louisville_cardinals_vs_miami_hurricanes_full_highlights"\n'
#  '              }\n'
#  '            }\n'
#  '          ],\n'
#  '          "headlines": [\n'
#  '            {\n'
#  '              "type": "Recap",\n'
#  '              "description": "\\u2014 Louisville tried a little bit of '
#  'everything. A fake field goal. Having three different players taking snaps '
#  'from center. A reverse that wasn\\u2019t a reverse.",\n'
#  '              "shortLinkText": "Louisville intercepts 4 of Beck\'s passes, '
#  'tops No. 2 Miami 24-21 to end Hurricanes\' home streak",\n'
#  '              "video": [\n'
#  '                {\n'
#  '                  "id": 46632233,\n'
#  '                  "source": "espn",\n'
#  '                  "headline": "Louisville Cardinals vs. Miami Hurricanes: '
#  'Full Highlights",\n'
#  '                  "thumbnail": '
#  '"https://a.espncdn.com/media/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.jpg",\n'
#  '                  "duration": 94,\n'
#  '                  "tracking": {\n'
#  '                    "sportName": "football",\n'
#  '                    "leagueName": "NCAA Football",\n'
#  '                    "coverageType": "Final Game Highlight",\n'
#  '                    "trackingName": "NCF_One-Play (Louisville Cardinals vs. '
#  'Miami Hurricanes: Full Highlights) 2025/10/17 ESHEET",\n'
#  '                    "trackingId": '
#  '"dm_20251017_NCF_louisville_cardinals_vs_miami_hurricanes_full_highlights"\n'
#  '                  },\n'
#  '                  "deviceRestrictions": {\n'
#  '                    "type": "whitelist",\n'
#  '                    "devices": [\n'
#  '                      "desktop",\n'
#  '                      "ipad",\n'
#  '                      "settop",\n'
#  '                      "handset",\n'
#  '                      "tablet"\n'
#  '                    ]\n'
#  '                  },\n'
#  '                  "links": {\n'
#  '                    "web": {\n'
#  '                      "href": '
#  '"https://www.espn.com/video/clip?id=46632233",\n'
#  '                      "self": {\n'
#  '                        "href": '
#  '"https://www.espn.com/video/clip?id=46632233",\n'
#  '                        "dsi": {\n'
#  '                          "href": '
#  '"https://www.espn.com/video/clip?id=1b08359549a0a"\n'
#  '                        }\n'
#  '                      },\n'
#  '                      "seo": {\n'
#  '                        "href": '
#  '"https://www.espn.com/video/clip/_/id/46632233"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "mobile": {\n'
#  '                      "source": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.mp4"\n'
#  '                      },\n'
#  '                      "alert": {\n'
#  '                        "href": '
#  '"https://m.espn.com/general/video/videoAlert?vid=46632233"\n'
#  '                      },\n'
#  '                      "streaming": {\n'
#  '                        "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46632233"\n'
#  '                      },\n'
#  '                      "progressiveDownload": {\n'
#  '                        "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46632233"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "api": {\n'
#  '                      "self": {\n'
#  '                        "href": '
#  '"https://content.core.api.espn.com/v1/video/clips/46632233"\n'
#  '                      },\n'
#  '                      "artwork": {\n'
#  '                        "href": '
#  '"https://artwork.api.espn.com/artwork/collections/media/f9a3cca2-afc0-4685-ad11-f807c1233f39"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "source": {\n'
#  '                      "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_360p30_1464k.mp4",\n'
#  '                      "mezzanine": {\n'
#  '                        "href": '
#  '"https://media.video-origin.espn.com/espnvideo/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.mp4"\n'
#  '                      },\n'
#  '                      "flash": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892.smil"\n'
#  '                      },\n'
#  '                      "hds": {\n'
#  '                        "href": '
#  '"https://hds.video-cdn.espn.com/z/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_rel.smil/manifest.f4m"\n'
#  '                      },\n'
#  '                      "HLS": {\n'
#  '                        "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8",\n'
#  '                        "HD": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                        },\n'
#  '                        "cmaf": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8",\n'
#  '                          "9x16": {\n'
#  '                            "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                          }\n'
#  '                        },\n'
#  '                        "9x16": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892/playlist.m3u8"\n'
#  '                        },\n'
#  '                        "shield": {\n'
#  '                          "href": '
#  '"https://watch.auth.api.espn.com/video/auth/media/f9a3cca2-afc0-4685-ad11-f807c1233f39/asset"\n'
#  '                        }\n'
#  '                      },\n'
#  '                      "HD": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_720p30_2896k.mp4"\n'
#  '                      },\n'
#  '                      "full": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1018/ffc491f4-3854-4fcc-be25-0a3d01a4f892/ffc491f4-3854-4fcc-be25-0a3d01a4f892_360p30_1464k.mp4"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "sportscenter": {\n'
#  '                      "href": '
#  '"sportscenter://x-callback-url/showVideo?videoID=46632233&videoDSI=1b08359549a0a"\n'
#  '                    }\n'
#  '                  }\n'
#  '                }\n'
#  '              ]\n'
#  '            }\n'
#  '          ]\n'
#  '        }\n'
#  '      ],\n'
#  '      "links": [\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "summary",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/game/_/gameId/401754564/louisville-miami",\n'
#  '          "text": "Gamecast",\n'
#  '          "shortText": "Gamecast",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "boxscore",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/boxscore/_/gameId/401754564",\n'
#  '          "text": "Box Score",\n'
#  '          "shortText": "Box Score",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "highlights",\n'
#  '            "desktop"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/video?gameId=401754564",\n'
#  '          "text": "Highlights",\n'
#  '          "shortText": "Highlights",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "pbp",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/playbyplay/_/gameId/401754564",\n'
#  '          "text": "Play-by-Play",\n'
#  '          "shortText": "Play-by-Play",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "recap",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/recap?gameId=401754564",\n'
#  '          "text": "Recap",\n'
#  '          "shortText": "Recap",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        }\n'
#  '      ],\n'
#  '      "status": {\n'
#  '        "clock": 0.0,\n'
#  '        "displayClock": "0:00",\n'
#  '        "period": 4,\n'
#  '        "type": {\n'
#  '          "id": "3",\n'
#  '          "name": "STATUS_FINAL",\n'
#  '          "state": "post",\n'
#  '          "completed": true,\n'
#  '          "description": "Final",\n'
#  '          "detail": "Final",\n'
#  '          "shortDetail": "Final"\n'
#  '        }\n'
#  '      }\n'
#  '    },\n'
#  '    {\n'
#  '      "id": "401752872",\n'
#  '      "uid": "s:20~l:23~e:401752872",\n'
#  '      "date": "2025-10-18T00:00Z",\n'
#  '      "name": "Nebraska Cornhuskers at Minnesota Golden Gophers",\n'
#  '      "shortName": "NEB @ MINN",\n'
#  '      "season": {\n'
#  '        "year": 2025,\n'
#  '        "type": 2,\n'
#  '        "slug": "regular-season"\n'
#  '      },\n'
#  '      "week": {\n'
#  '        "number": 8\n'
#  '      },\n'
#  '      "competitions": [\n'
#  '        {\n'
#  '          "id": "401752872",\n'
#  '          "uid": "s:20~l:23~e:401752872~c:401752872",\n'
#  '          "date": "2025-10-18T00:00Z",\n'
#  '          "attendance": 48549,\n'
#  '          "type": {\n'
#  '            "id": "1",\n'
#  '            "abbreviation": "STD"\n'
#  '          },\n'
#  '          "timeValid": true,\n'
#  '          "dateValid": false,\n'
#  '          "neutralSite": false,\n'
#  '          "conferenceCompetition": true,\n'
#  '          "playByPlayAvailable": true,\n'
#  '          "recent": false,\n'
#  '          "venue": {\n'
#  '            "id": "3953",\n'
#  '            "fullName": "Huntington Bank Stadium",\n'
#  '            "address": {\n'
#  '              "city": "Minneapolis",\n'
#  '              "state": "MN",\n'
#  '              "country": "USA"\n'
#  '            },\n'
#  '            "indoor": false\n'
#  '          },\n'
#  '          "competitors": [\n'
#  '            {\n'
#  '              "id": "135",\n'
#  '              "uid": "s:20~l:23~t:135",\n'
#  '              "type": "team",\n'
#  '              "order": 0,\n'
#  '              "homeAway": "home",\n'
#  '              "winner": true,\n'
#  '              "team": {\n'
#  '                "id": "135",\n'
#  '                "uid": "s:20~l:23~t:135",\n'
#  '                "location": "Minnesota",\n'
#  '                "name": "Golden Gophers",\n'
#  '                "abbreviation": "MINN",\n'
#  '                "displayName": "Minnesota Golden Gophers",\n'
#  '                "shortDisplayName": "Minnesota",\n'
#  '                "color": "5e0a2f",\n'
#  '                "alternateColor": "fab41c",\n'
#  '                "isActive": true,\n'
#  '                "venue": {\n'
#  '                  "id": "3953"\n'
#  '                },\n'
#  '                "links": [\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/135/minnesota-golden-gophers",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "clubhouse",\n'
#  '                      "mobile",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/_/id/135/minnesota-golden-gophers",\n'
#  '                    "text": "Clubhouse",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "roster",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/roster/_/id/135",\n'
#  '                    "text": "Roster",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "stats",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/stats/_/id/135",\n'
#  '                    "text": "Statistics",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  },\n'
#  '                  {\n'
#  '                    "rel": [\n'
#  '                      "schedule",\n'
#  '                      "desktop",\n'
#  '                      "team"\n'
#  '                    ],\n'
#  '                    "href": '
#  '"https://www.espn.com/college-football/team/schedule/_/id/135",\n'
#  '                    "text": "Schedule",\n'
#  '                    "isExternal": false,\n'
#  '                    "isPremium": false\n'
#  '                  }\n'
#  '                ],\n'
#  '                "logo": '
#  '"https://a.espncdn.com/i/teamlogos/ncaa/500/135.png",\n'
#  '                "conferenceId": "5"\n'
#  '              },\n'
#  '              "score": "24",\n'
#  '              "linescores": [\n'
#  '                {\n'
#  '                  "value": 0.0,\n'
#  '                  "displayValue": "0",\n'
#  '                  "period": 1\n'
#  '                },\n'
# ...
#  '                  "ipad",\n'
#  '                  "settop",\n'
#  '                  "handset",\n'
#  '                  "tablet"\n'
#  '                ]\n'
#  '              },\n'
#  '              "thumbnail": '
#  '"https://a.espncdn.com/media/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.jpg",\n'
#  '              "links": {\n'
#  '                "web": {\n'
#  '                  "href": "https://www.espn.com/video/clip?id=46644654",\n'
#  '                  "self": {\n'
#  '                    "href": "https://www.espn.com/video/clip?id=46644654",\n'
#  '                    "dsi": {\n'
#  '                      "href": '
#  '"https://www.espn.com/video/clip?id=9112fa2bb6c9c"\n'
#  '                    }\n'
#  '                  },\n'
#  '                  "seo": {\n'
#  '                    "href": "https://www.espn.com/video/clip/_/id/46644654"\n'
#  '                  }\n'
#  '                },\n'
#  '                "mobile": {\n'
#  '                  "source": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.mp4"\n'
#  '                  },\n'
#  '                  "alert": {\n'
#  '                    "href": '
#  '"https://m.espn.com/general/video/videoAlert?vid=46644654"\n'
#  '                  },\n'
#  '                  "streaming": {\n'
#  '                    "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/bdbf4f42-d088-4609-99e8-73662db10609/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46644654"\n'
#  '                  },\n'
#  '                  "progressiveDownload": {\n'
#  '                    "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/bdbf4f42-d088-4609-99e8-73662db10609/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46644654"\n'
#  '                  }\n'
#  '                },\n'
#  '                "api": {\n'
#  '                  "self": {\n'
#  '                    "href": '
#  '"https://content.core.api.espn.com/v1/video/clips/46644654"\n'
#  '                  },\n'
#  '                  "artwork": {\n'
#  '                    "href": '
#  '"https://artwork.api.espn.com/artwork/collections/media/bdbf4f42-d088-4609-99e8-73662db10609"\n'
#  '                  }\n'
#  '                },\n'
#  '                "source": {\n'
#  '                  "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_360p30_1464k.mp4",\n'
#  '                  "mezzanine": {\n'
#  '                    "href": '
#  '"https://media.video-origin.espn.com/espnvideo/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.mp4"\n'
#  '                  },\n'
#  '                  "flash": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.smil"\n'
#  '                  },\n'
#  '                  "hds": {\n'
#  '                    "href": '
#  '"https://hds.video-cdn.espn.com/z/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_rel.smil/manifest.f4m"\n'
#  '                  },\n'
#  '                  "HLS": {\n'
#  '                    "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8",\n'
#  '                    "HD": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                    },\n'
#  '                    "cmaf": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8",\n'
#  '                      "9x16": {\n'
#  '                        "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "9x16": {\n'
#  '                      "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                    },\n'
#  '                    "shield": {\n'
#  '                      "href": '
#  '"https://watch.auth.api.espn.com/video/auth/media/bdbf4f42-d088-4609-99e8-73662db10609/asset"\n'
#  '                    }\n'
#  '                  },\n'
#  '                  "HD": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_720p30_2896k.mp4"\n'
#  '                  },\n'
#  '                  "full": {\n'
#  '                    "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_360p30_1464k.mp4"\n'
#  '                  }\n'
#  '                },\n'
#  '                "sportscenter": {\n'
#  '                  "href": '
#  '"sportscenter://x-callback-url/showVideo?videoID=46644654&videoDSI=9112fa2bb6c9c"\n'
#  '                }\n'
#  '              },\n'
#  '              "ad": {\n'
#  '                "sport": "ncf",\n'
#  '                "bundle": "ncf_highlights"\n'
#  '              },\n'
#  '              "tracking": {\n'
#  '                "sportName": "football",\n'
#  '                "leagueName": "NCAA Football",\n'
#  '                "coverageType": "Final Game Highlight",\n'
#  '                "trackingName": "NCF_One-Play (Cincinnati Bearcats vs. '
#  'Oklahoma State Cowboys: Full Highlights) 2025/10/19 ESHEET",\n'
#  '                "trackingId": '
#  '"dm_20251019_NCF_cincinnati_bearcats_vs_oklahoma_state_cowboys_full_highlights"\n'
#  '              }\n'
#  '            }\n'
#  '          ],\n'
#  '          "headlines": [\n'
#  '            {\n'
#  '              "type": "Recap",\n'
#  '              "description": "\\u2014 Brendan Sorsby threw three touchdown '
#  'passes and ran for a score and No. 24 Cincinnati took control late and beat '
#  'Oklahoma State 49-17 on Saturday night for its sixth straight victory.",\n'
#  '              "shortLinkText": "Sorsby has hand in 4 TDs in No. 24 '
#  'Cincinnati\'s 49-17 victory over Oklahoma State",\n'
#  '              "video": [\n'
#  '                {\n'
#  '                  "id": 46644654,\n'
#  '                  "source": "espn",\n'
#  '                  "headline": "Cincinnati Bearcats vs. Oklahoma State '
#  'Cowboys: Full Highlights",\n'
#  '                  "thumbnail": '
#  '"https://a.espncdn.com/media/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.jpg",\n'
#  '                  "duration": 67,\n'
#  '                  "tracking": {\n'
#  '                    "sportName": "football",\n'
#  '                    "leagueName": "NCAA Football",\n'
#  '                    "coverageType": "Final Game Highlight",\n'
#  '                    "trackingName": "NCF_One-Play (Cincinnati Bearcats vs. '
#  'Oklahoma State Cowboys: Full Highlights) 2025/10/19 ESHEET",\n'
#  '                    "trackingId": '
#  '"dm_20251019_NCF_cincinnati_bearcats_vs_oklahoma_state_cowboys_full_highlights"\n'
#  '                  },\n'
#  '                  "deviceRestrictions": {\n'
#  '                    "type": "whitelist",\n'
#  '                    "devices": [\n'
#  '                      "desktop",\n'
#  '                      "ipad",\n'
#  '                      "settop",\n'
#  '                      "handset",\n'
#  '                      "tablet"\n'
#  '                    ]\n'
#  '                  },\n'
#  '                  "links": {\n'
#  '                    "web": {\n'
#  '                      "href": '
#  '"https://www.espn.com/video/clip?id=46644654",\n'
#  '                      "self": {\n'
#  '                        "href": '
#  '"https://www.espn.com/video/clip?id=46644654",\n'
#  '                        "dsi": {\n'
#  '                          "href": '
#  '"https://www.espn.com/video/clip?id=9112fa2bb6c9c"\n'
#  '                        }\n'
#  '                      },\n'
#  '                      "seo": {\n'
#  '                        "href": '
#  '"https://www.espn.com/video/clip/_/id/46644654"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "mobile": {\n'
#  '                      "source": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.mp4"\n'
#  '                      },\n'
#  '                      "alert": {\n'
#  '                        "href": '
#  '"https://m.espn.com/general/video/videoAlert?vid=46644654"\n'
#  '                      },\n'
#  '                      "streaming": {\n'
#  '                        "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/bdbf4f42-d088-4609-99e8-73662db10609/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46644654"\n'
#  '                      },\n'
#  '                      "progressiveDownload": {\n'
#  '                        "href": '
#  '"https://watch.auth.api.espn.com/video/auth/brightcove/bdbf4f42-d088-4609-99e8-73662db10609/asset?UMADPARAMreferer=https://www.espn.com/video/clip?id=46644654"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "api": {\n'
#  '                      "self": {\n'
#  '                        "href": '
#  '"https://content.core.api.espn.com/v1/video/clips/46644654"\n'
#  '                      },\n'
#  '                      "artwork": {\n'
#  '                        "href": '
#  '"https://artwork.api.espn.com/artwork/collections/media/bdbf4f42-d088-4609-99e8-73662db10609"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "source": {\n'
#  '                      "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_360p30_1464k.mp4",\n'
#  '                      "mezzanine": {\n'
#  '                        "href": '
#  '"https://media.video-origin.espn.com/espnvideo/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.mp4"\n'
#  '                      },\n'
#  '                      "flash": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc.smil"\n'
#  '                      },\n'
#  '                      "hds": {\n'
#  '                        "href": '
#  '"https://hds.video-cdn.espn.com/z/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_rel.smil/manifest.f4m"\n'
#  '                      },\n'
#  '                      "HLS": {\n'
#  '                        "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8",\n'
#  '                        "HD": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                        },\n'
#  '                        "cmaf": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8",\n'
#  '                          "9x16": {\n'
#  '                            "href": '
#  '"https://service-pkgespn.akamaized.net/opp/cmaf/espn/9x16/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                          }\n'
#  '                        },\n'
#  '                        "9x16": {\n'
#  '                          "href": '
#  '"https://service-pkgespn.akamaized.net/opp/hls/espn/9x16/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc/playlist.m3u8"\n'
#  '                        },\n'
#  '                        "shield": {\n'
#  '                          "href": '
#  '"https://watch.auth.api.espn.com/video/auth/media/bdbf4f42-d088-4609-99e8-73662db10609/asset"\n'
#  '                        }\n'
#  '                      },\n'
#  '                      "HD": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_720p30_2896k.mp4"\n'
#  '                      },\n'
#  '                      "full": {\n'
#  '                        "href": '
#  '"https://media.video-cdn.espn.com/motion/wsc/2025/1019/24658144-d4fc-47a7-8d82-b7b4da3b11fc/24658144-d4fc-47a7-8d82-b7b4da3b11fc_360p30_1464k.mp4"\n'
#  '                      }\n'
#  '                    },\n'
#  '                    "sportscenter": {\n'
#  '                      "href": '
#  '"sportscenter://x-callback-url/showVideo?videoID=46644654&videoDSI=9112fa2bb6c9c"\n'
#  '                    }\n'
#  '                  }\n'
#  '                }\n'
#  '              ]\n'
#  '            }\n'
#  '          ]\n'
#  '        }\n'
#  '      ],\n'
#  '      "links": [\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "summary",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/game/_/gameId/401756926/cincinnati-oklahoma-st",\n'
#  '          "text": "Gamecast",\n'
#  '          "shortText": "Gamecast",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "boxscore",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/boxscore/_/gameId/401756926",\n'
#  '          "text": "Box Score",\n'
#  '          "shortText": "Box Score",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "highlights",\n'
#  '            "desktop"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/video?gameId=401756926",\n'
#  '          "text": "Highlights",\n'
#  '          "shortText": "Highlights",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "pbp",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/playbyplay/_/gameId/401756926",\n'
#  '          "text": "Play-by-Play",\n'
#  '          "shortText": "Play-by-Play",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        },\n'
#  '        {\n'
#  '          "language": "en-US",\n'
#  '          "rel": [\n'
#  '            "recap",\n'
#  '            "desktop",\n'
#  '            "event"\n'
#  '          ],\n'
#  '          "href": '
#  '"https://www.espn.com/college-football/recap?gameId=401756926",\n'
#  '          "text": "Recap",\n'
#  '          "shortText": "Recap",\n'
#  '          "isExternal": false,\n'
#  '          "isPremium": false\n'
#  '        }\n'
#  '      ],\n'
#  '      "status": {\n'
#  '        "clock": 0.0,\n'
#  '        "displayClock": "0:00",\n'
#  '        "period": 4,\n'
#  '        "type": {\n'
#  '          "id": "3",\n'
#  '          "name": "STATUS_FINAL",\n'
#  '          "state": "post",\n'
#  '          "completed": true,\n'
#  '          "description": "Final",\n'
#  '          "detail": "Final",\n'
#  '          "shortDetail": "Final"\n'
#  '        }\n'
#  '      }\n'
#  '    }\n'
#  '  ]\n'
#  '}')
